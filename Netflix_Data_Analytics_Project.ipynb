# %% [markdown]
# # Data Analytics Internship Project
# ## Netflix Data Analysis
#
# For this project, I will be analyzing the Netflix dataset to find some interesting trends. I will use pandas, matplotlib and seaborn for Data Analysis and Visualization.

# %%
# Importing required libraries for analysis
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# to ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### 1. Loading Data
# First, I will load the dataset using pandas read_csv method.

# %%
# load the csv file
df = pd.read_csv('netflix_titles.csv')

# printing first 5 rows to see how data looks
df.head()

# %% [markdown]
# ### 2. Checking Data Info
# Let's check the shape and columns of the dataset to understand it better.

# %%
# check total rows and columns
print("Shape:", df.shape)

# print all column names
print("Columns:", df.columns)

# %% [markdown]
# ### 3. Missing Values
# Now I will check if there are any null values in our dataset which needs cleaning.

# %%
# finding missing values
missing_vals = df.isnull().sum()
print(missing_vals[missing_vals > 0])

# %% [markdown]
# ### 4. Summary Statistics
# Let's use the describe function to see some basic stats about the data.

# %%
# using describe to get stats
df.describe(include='all')

# %% [markdown]
# ### 5. Analyzing Patterns
# I want to see the difference between the number of movies and TV shows, and also which country produces the most content.

# %%
# check count of movies and tv shows
type_counts = df['type'].value_counts()
print(type_counts)

print("\n")
# top 5 countries
top_countries = df['country'].value_counts().head(5)
print(top_countries)

# %% [markdown]
# ### 6. Data Visualization
# Here I will create some graphs using matplotlib and seaborn to visualize the data properly.

# %% [markdown]
# #### 1. Checking Missing Data with Heatmap
# First, a heatmap to see visually where the data is missing.

# %%
plt.figure(figsize=(10,6))
# plot heatmap for null values
sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap='viridis')
plt.title('Missing Data Heatmap')
plt.show()

# %% [markdown]
# #### 2. Movies vs TV Shows Pie Chart
# Let's visualize the distribution of content types.

# %%
plt.figure(figsize=(6,6))
plt.pie(type_counts, labels=type_counts.index, autopct='%1.1f%%', colors=['#ff9999','#66b3ff'])
plt.title('Movies vs TV Shows')
plt.show()

# %% [markdown]
# #### 3. Top 10 Countries Bar Chart
# Plotting a bar chart to see the top countries producing netflix content.

# %%
plt.figure(figsize=(10,5))
top_10 = df['country'].value_counts().head(10)
sns.barplot(x=top_10.values, y=top_10.index, palette='Blues_r')
plt.title('Top 10 Countries')
plt.xlabel('Count')
plt.ylabel('Country Name')
plt.show()

# %% [markdown]
# #### 4. Release Year Histogram
# Let's see the trend of content added over the years. I will only consider data after year 2000 for better graph.

# %%
plt.figure(figsize=(10,5))
df_recent = df[df['release_year'] >= 2000]
sns.histplot(df_recent['release_year'], bins=20, color='purple', kde=True)
plt.title('Content Release By Year')
plt.xlabel('Year')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### 7. Content Rating Analysis
# Let's analyze which age groups or maturity ratings have the most content on Netflix.

# %%
plt.figure(figsize=(12,6))
# creating a countplot for ratings
sns.countplot(x='rating', data=df, order=df['rating'].value_counts().index, palette='magma')
plt.title('Content Ratings on Netflix')
plt.xlabel('Rating Maturity')
plt.ylabel('Count of Movies and Shows')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### 8. Genre Distribution (Top 10)
# Let's check out the top 10 most popular genres on Netflix using the `listed_in` column.

# %%
plt.figure(figsize=(12,6))
top_genres = df['listed_in'].value_counts().head(10)
# creating a barplot for top genres
sns.barplot(x=top_genres.values, y=top_genres.index, palette='cubehelix')
plt.title('Top 10 Genres on Netflix')
plt.xlabel('Count')
plt.ylabel('Genre')
plt.show()

# %% [markdown]
# ### 9. Filtering Specific Data (Data Extraction)
# Sometimes we only want to see data for one specific country or category. Here I am filtering the dataframe to only show 'Movies' made in 'India'.

# %%
# filter the data where country is India and type is Movie
indian_movies = df[(df['country'] == 'India') & (df['type'] == 'Movie')]

# showing the first 3 results to verify
indian_movies.head(3)

# %% [markdown]
# ### Conclusion
# Based on my complete analysis of the Netflix dataset, I found out following things:
# 1. Netflix has lot more Movies (around 70%) compared to TV shows.
# 2. Most of the content on Netflix comes from the United States, followed by India.
# 3. Heatmap visualization perfectly highlights that `director`, `cast`, and `country` columns have a lot of missing values.
# 4. Netflix started producing/adding content rapidly after 2015 based on the histogram.
# 5. `TV-MA` and `TV-14` are the most common ratings, showing Netflix caters heavily to mature and teen audiences.
# 6. "Documentaries" and "Stand-Up Comedy" are surprisingly among the top most common genres, right alongside International Movies.
#
# This was a very informative project that taught me a lot about filtering data, extracting patterns, and visualizing results in Python.
